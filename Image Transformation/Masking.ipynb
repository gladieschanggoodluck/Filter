# %% [markdown]
# # Mask the region of interest so we can focus our search effort for what we want

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline
image_color = cv2.imread('image_lane.jpg')

cv2.imshow('Original', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width = image_color.shape[:2]

# %%
height
# Out:
# 1536

# %%
width
# Out:
# 2048

# %%
plt.imshow(image_color)

# %% [markdown]
# # Convert to greyscale

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (1536, 2048)

# %% [markdown]
# # Perform region of interest masking

# %%
# Select points of the region of interest(ROI)
ROI = np.array([[(0, height), (1000, 900), (1100, 900), (width, height)]], dtype = np.int32)
# define a blank image with all zeros(ie: black)
blank = np.zeros_like(image_gray)
# Fill the Region of interest with white color(ie: 255)
mask = cv2.fillPoly(blank, ROI, 255)
# Perform bitwise AND operation to select only the region of itnerest
masked_image = cv2.bitwise_and(image_gray, mask)

# %%
masked_image.shape
# Out:
# (1536, 2048)

# %%
plt.imshow(masked_image, cmap = 'gray')
