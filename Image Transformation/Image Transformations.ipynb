# %% [markdown]
# # Image transformations aare sued to correct distorations and/or change perspectives
# - M: Transformation matrix (source points --> destination points)
# - M = cv2.getPerspectiveTransform(Source_points, Destination_points)
# - warped = cv2.warpPerspective(image, N, (width, height))

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline
image = cv2.imread('Speed_Sign.jpg')
cv2.imshow('Original image', image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
image = mpimg.imread('Speed_Sign.jpg')
plt.imshow(image)

# %%
height, width = image.shape[:2]

# %%
height
# Out:
# 394

# %%
width
# Out:
# 700

# %%
# First entry : top-left,
# Second entry: top-right
# Third: bottom-right
#Forth: bottom-left
#Cordinates of the 4 corners of the original image
Source_points = np.float32([[150, 100], [410, 70], [410, 590], [140, 550]])
# Coordinaates of the 4 corners of the desired output
Destination_points = np.float32([[0, 0], [width, 0], [width, height], [0, height]])

# %%
# Use the two sets of four points to compute
# the Perspective Transformation matrix, M
M = cv2.getPerspectiveTransform(Source_points, Destination_points)
warped = cv2.warpPerspective(image, M, (width, height))

cv2.imshow('warped Image', warped)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
